# %%
import os
from ultralytics import YOLO
import cv2
model = YOLO("yolov8n.yaml")
results = model.train(
    data="C:/Users/X/Desktop/yolov8dataset/X1.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    device='0',
    lr0=0.005,
    augment= True,
    iou=0.5
)
# Out:
# Ultralytics 8.3.21  Python-3.12.3 torch-2.4.1 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
# ...

# %%
model = YOLO("runs/detect/train/weights/best.pt")
metrics = model.val(data="C:/Users/X/Desktop/yolov8dataset/X1.yaml")
print(f"mAP@50:{metrics.box.map50}")
print(f"mAP@75:{metrics.box.map75}")
print(f"mAP@50-95:{metrics.box.maps}")
# Out:
# Ultralytics 8.3.21  Python-3.12.3 torch-2.4.1 CUDA:0 (NVIDIA GeForce RTX 4070 Laptop GPU, 8188MiB)
# YOLOv8n summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\X\Desktop\YOLO DATASET\valid\labels.cache... 2455 images, 4 backgrounds, 0 corrupt: 100%|██████████| 2455/2455 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 154/154 [00:11<00:00, 12.86it/s]
#                    all       2455       2614      0.957      0.962      0.989      0.908
# Speed: 0.2ms preprocess, 1.9ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs\detect\val
# mAP@50: 0.9885957916574994
# mAP@75: 0.9652681302586253
# mAP@50-95: [    0.90797]
